# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='Literal answer: There isn’t one. The Moon isn’t a country and has no government, so it has no capital.\n\nWordplay answer (a riddle): The capital letter of the word "Moon" is M.\n\nIf you’re writing science fiction and want a fictional capital, you could use names like Lunopolis, Selene City, or Luna Capitale.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1235, 'prompt_tokens': 13, 'total_tokens': 1248, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DASkOhPQhFYYjTqoE9H4Q1dZcSn63', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c6ed7-b03f-74b3-9d68-ff856e8a32d9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1235, 'total_tokens': 1248, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}})

# %%
print(response.content)
# Out:
# Literal answer: There isn’t one. The Moon isn’t a country and has no government, so it has no capital.
#
# Wordplay answer (a riddle): The capital letter of the word "Moon" is M.
#
# If you’re writing science fiction and want a fictional capital, you could use names like Lunopolis, Selene City, or Luna Capitale.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DASkOhPQhFYYjTqoE9H4Q1dZcSn63',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 1235,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 1152,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 1248}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital, cities, or political divisions. If you’re thinking of a fictional setting or future plans for lunar bases, tell me the context and I can name a proposed capital from that universe.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory with a government. It's Earth's natural satellite - a celestial body with no permanent population or political structure.
#
# If you're asking about lunar settlements in science fiction, or perhaps thinking about future colonization, there are no real cities or capitals on the Moon yet, though various countries and private companies are planning future lunar bases.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's not a country with a government or defined settlements.
#
# However, if we were to imagine a hypothetical capital, it might be located at:
#
# *   **The Sea of Tranquility (Mare Tranquillitatis):** This is where the Apollo 11 mission landed, making it a historically significant location for humanity's first steps on the Moon. It's a very recognizable and iconic spot.
#
# But remember, this is purely imaginative!

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='852b9d19-979b-4ac5-a04c-0cfb2e98db01'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. Any future settlements would be governed within a framework set by Earth nations or international agreements, not by a capital city. If you’re asking about a fictional work, I can name the capital from that story.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 452, 'prompt_tokens': 13, 'total_tokens': 465, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DASmgbZwCoogm3XpOTnBtKmuk8v34', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c6ed9-dbd5-7f60-b470-cf26967ee5e5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 452, 'total_tokens': 465, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. Any future settlements would be governed within a framework set by Earth nations or international agreements, not by a capital city. If you’re asking about a fictional work, I can name the capital from that story.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='033c8533-a95b-4681-9817-b5adce04e2d9'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='b0e6bcad-a8d7-43ee-b522-8082fd5f0da5', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='8883e9e2-07f9-4007-96a2-9e422c487a37'),
#               AIMessage(content='Luna City is a fictional concept (there isn’t a real capital on the Moon). Here’s one coherent take you can use for a story, game, or worldbuilding.\n\nOverview\n- Luna City is the political and cultural capital of a lunar federation that governs settlements and research outposts on the Moon. It sits in a large, shielded lava-tube crater on the near side, where it enjoys regular Earth communication and a dramatic view of Earthrise.\n\nGeography and infrastructure\n- Location: A protected crater in Mare Tranquillitatis or a similar near-side basin, chosen for natural shielding and access to ice-rich regions.\n- Core layout: A central Civic Spire anchors a network of concentric rings—residential, industrial, research, and agricultural districts—connected by a transit tunnel system and magnetically levitated trams.\n- Housing and habitats: Sunlit, pressurized dome clusters with inflatable modules and 3D-printed regolith structures for radiation shielding. Most living spaces are modular and reconfigurable.\n- Energy and life support: Solar farms on the crater rim feed a thermal-energy storage system; ISRU (in-situ resource utilization) facilities extract water from ice and oxygen from regolith, supporting a closed-loop water and air system.\n- Transportation: Lunar rovers for surface work, subterranean transit tunnels for rapid travel, and a vertical lift system within the Civic Spire for urgent access to the command deck.\n\nGovernment and society\n- Political structure: The Lunar Council oversees urban planning, research priorities, and resource allocation, with representation from major orbital bases and surface settlements. Earth remains a federative partner with defense and diplomatic responsibilities.\n- Law and order: A Lunar Constitution guarantees autonomy in daily governance, with Earth-based authority limited to interplanetary treaties and safety standards.\n- Citizenship and participation: Residents can gain citizenship through service—science, mining, education, or infrastructure projects—and vote on local referenda and long-term initiatives like expansion or terraforming trials.\n- Education and culture: A fusion of scientific institutes, arts academies, and public learning centers. The city hosts rotating exhibits on lunar history, Earth-Moon art exchanges, and inter-colony conferences.\n\nEconomy and technology\n- Main industries: Helium-3 and water-ice extraction, high-precision manufacturing using lunar-regolith composites, life-support technology, and space research facilities.\n- Currency and trade: A lunar credit system tied to Earth-based markets but backed by essential goods (water, oxygen, tech licenses). The central mint prints standardized currency for lunar use.\n- Tech highlights: Advanced 3D printing with regolith, autonomous maintenance bots, AI-assisted life support, radiation-hardened networking, and a robust lunar GPS-like navigation system for surface operations.\n\nCulture and daily life\n- Neighborhoods: Founders’ Crescent (historic district honoring early settlers), Scholar’s Quarter (universities and think tanks), Arts District (theater, holographic galleries, lunar opera), and the Night Market (durable goods, food grown in hydroponics).\n- Work life: Three-shift system synchronized with Earth communications; most people spend part of their day in research, manufacturing, or governance, with downtime in communal gardens, museums, and theaters.\n- Health and wellness: Zero-gee fitness zones, lunar gravity clinics, radiation shelters, and mental-health pods designed to help residents cope with long lunar nights and isolation.\n- Cuisine: A blend of Earth imports and in-situ grown produce—crisp hydroponic greens, algae-based proteins, and processed regolith-derived minerals as flavor components.\n\nLandmarks and notable places\n- The Civic Spire: The tallest centerpiece housing government chambers, emergency operations, and a public observation deck.\n- Lumen Dome ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional setting—the capital of the Moon. There isn’t a real Luna City in our history, but I can give you a rich, detailed worldbuilding concept you can use for a story, game, or world. If you want it tailored to a particular genre (hard sci-fi, space opera, steampunk, etc.), tell me and I’ll adjust.
#
# Quick concept at a glance
# - Name: Luna City
# - Role: Political and cultural capital of the Moon; seat of lunar government and a hub for science, industry, and diplomacy between Earth and lunar settlements.
# - Location: A polar region near the Moon’s south pole, integrated into a network of lava tubes and crater basins, with extensive shielding and energy infrastructure.
# - Government: A semi-autonomous lunar state under a constitutional framework called the Lunar Commonwealth; a powerful city council (The Crescent Senate) governs with a rotating executive office and a judicial lattice of lunar courts.
# - Population: A diverse mix of Earth-born administrators, scientist-explorers, and Moon-born settlers who grew up in the caves and domes.
# - Economy: Research and development (AI, life-support tech, in-situ resource use), water ice mining, helium-3 and rare mineral extraction, high-grade manufacturing, and tourism/education.
# - Culture: A blend of Earth cultures with distinct lunar habits and slang; emphasis on science, resilience, and communal rituals around the day-night cycle and resource stewardship.
#
# World bible — the core elements
#
# 1) Geography and location
# - Setting: The city sits in a permanently shadowed or near-shadowed zone at the south pole, leveraging sunlight through reflective regolith, solar concentrators, and a web of lava-tube corridors that keep habitats stable and shielded.
# - Urban fabric: A central “Dome Spine” (a ring of interconnected habitat domes) sits above a basin of ice and ore. Sub-surface lava tubes host long corridors, storage, and transit tunnels. Surface districts are protected by regolith shielding and transparent lunar glass for light without heat loss.
# - Districts:
#   - Horizon Dome District: Government halls, legislative complexes, and the main archives.
#   - Iceworks Quarter: Water ice processing plants, airlocks, and hydroponic farms.
#   - Glass Sea Arcade: Public markets, museums, universities, and ceremonial spaces.
#   - Iron Spine Sector: Heavy manufacturing, kilns, and power generation facilities.
#   - Quiet Walks: Research stations, observatories, and think tanks.
# - Climate and hazards: No atmosphere, extreme radiation outside shielded zones, micro-meteoroid risk; constant life-support and shielding are essential. Gravity is 1/6th of Earth, influencing architecture and transport.
#
# 2) Government and politics
# - System: Lunar Commonwealth with a constitutional framework ensuring local autonomy for Luna City while coordinating with Earth-based authorities for resource sharing and defense.
# - Key bodies:
#   - The Crescent Senate: Legislation and oversight, with representatives from orbital colonies and surface districts.
#   - The Speaker and Lunar Executive Council: Administrative leadership chosen by rotation among senior council members.
#   - Lunar Court: A network of courts ensuring civil rights, resource disputes, and environmental protection for the lunar environment.
# - Powers and rights: Autonomy on most domestic matters, treaty-based resource sharing with Earth, electoral rules for lunar residents, and a charter protecting water, ice, and habitable habitats.
# - Challenges: Balancing Earth-descended corporate interests with citizen welfare, managing scarce water resources, dealing with radiation events, and maintaining security without provoking an interplanetary arms race.
#
# 3) History and timeline
# - Founding era: Early lunar outposts converge into Luna City as a political capital after the Solar Pact, a treaty aligning Earth and Moon settlements for shared governance and resource rights.
# - Key moments:
#   - The Ice Accord: A treaty securing water ice rights and refreezing of regolith for habitat stability.
#   - The Dark Bright Festival: A symbolic event around the cycle of long nights and brief sunlit windows, emphasizing resilience and community.
#   - The Network War (hypothetical): A conflict over transit routes in the lava tubes that was resolved through engineering diplomacy and shared infrastructure.
# - Modern era: Luna City hosts interplanetary conferences, hosts the Lunar University, and remains the hub for lunar diplomacy and science.
#
# 4) Economy and technology
# - Core sectors:
#   - In-situ resource use (ISRU): Water ice extraction, oxygen production, fuel synthesis, mineral refining from regolith.
#   - Helium-3 and rare minerals: Potential fuel and materials for advanced propulsion and quantum tech.
#   - High-tech manufacturing: Robotics, AI research, life-support systems, habitat modules, and shielding technologies.
#   - Research and education: Universities, think tanks, observatories, and citizen science programs.
#   - Tourism and culture: Museums, ice caves tours, lunar bazaars, and ceremonial sites.
# - Infrastructure drivers:
#   - Solar energy arrays and beamed power to keep habitats warm and functional.
#   - Regolith shielding using nano-coated glass, regolith blankets, and inflatable domes.
#   - Ground transportation through tunnel networks, mag-lev surface corridors, and vacuum pods.
# - Currency and trade: A lunar credit system backed by resource reserves and joint Earth-Lunar credit facilities; trade in water ice, metals, and high-end manufactured goods.
#
# 5) Society and culture
# - Inhabitants: Earth-born administrators, scientists, engineers, and lunar-born settlers who have grown up in domes and tubes.
# - Demographics: Multicultural mix; a strong sense of common purpose, with subcultures centered on districts, research fields, and craft guilds.
# - Language: A lingua franca of English and Mandarin in formal settings, with lunar slang and creoles developing in the habitations.
# - Daily life: Shift-based work schedules due to life-support and radiation protection; routines around the ~14-Earth-day cycle of daylight and darkness, with public spaces lit by bioluminescent flora and glass skylights.
# - Values and rituals: Resource stewardship, scientific curiosity, and communal resilience; annual festivals tied to the sunlit window and hydroponic harvests.
#
# 6) Architecture and infrastructure
# - Aesthetic: A blend of functional, shielded domes and elegant curves that maximize daylight inside while minimizing heat loss.
# - Materials: Basalt and regolith shielding, transparent lunar glass, advanced polymers, and locally produced metals.
# - Housing: Modular habitat domes connected by pressurized tunnels; private quarters, communal labs, and social hubs.
# - Public spaces: The Dome of Dawn (legislative heart), Ice Cathedral (water-ice sculpture and research center), Observatory Spire (astronomical and weather monitoring), and Market Arcades (trade and culture).
# - Transportation:
#   - Surface transit: Vacuum pods and mag-lev-like trains within protected corridors.
#   - Subsurface transit: Tunnels and tubes between districts to reduce radiation exposure.
#   - Walkways: Shielded promenades with kinetic energy absorbers for safety.
#
# 7) Science and education
# - Institutions:
#   - Lunar University: Advanced degrees in astrobiology, ISRU engineering, robotic systems, and lunar geology.
#   - The Ice Lab: Research into cryo-processing and water cycle management in lunar habitats.
#   - The Observatory Nexus: Space telescopes and planetary science facilities.
# - Research focus: Water ice dynamics, resource extraction efficiency, radiation shielding, life-support optimization, autonomous robotics, and sustainable lunar agriculture.
# - Public outreach: Citizen science programs, school partnerships, and museum programs that connect residents with ongoing research.
#
# 8) Security and resilience
# - Security posture: Civic guard and emergency response teams specialized for lunar environments; infrastructure protection from micrometeoroids, solar storms, and radiation bursts.
# - Disaster readiness: Redundant life-support systems, emergency shelters, and rapid repair crews; protocols for power outages and communication blackouts.
# - Diplomacy and defense: Peaceful stance with Earth allies; defense in depth via shielding, redundant power, and secure supply chains rather than conquest.
#
# 9) Landscapes, landmarks, and districts (sample)
# - The Crescent Senate Hall: A large, curved glass structure where laws are debated and public records are stored.
# - The Ice Cathedral: A crystalline chamber where water ice is processed and art installations glow with reflected light.
# - The Dawn Gate: A ceremonial entrance to the city with a sculpture depicting humanity’s first steps on the Moon.
# - The Glass Sea Arcade: Market district blending lunar crafts, algae-based cuisine, and holographic displays.
# - The Ice-Line Quarters: Residential zone with modular habitats and hydroponic courtyards.
# - The Iron Spine: Heavy industry and power generation hub, shielded from surface hazards.
# - The Observatory Spire: A central research tower with external solar and cosmic-ray monitoring equipment.
#
# 10) Daily life and culture tips
# - Timekeeping: A 29.5-day lunar day-night cycle influences work shifts, festivals, and daily rhythm.
# - Food: Hydroponic greens, algae-based proteins, and lab-grown pastries; cuisine emphasizes energy efficiency and flavor with limited resources.
# - Leisure: Ice cave excursions, zero-g gym spaces, virtual reality museums, and community labs for tinkering with robotics.
# - Etiquette: Emphasis on community service, resource responsibility, and mutual aid; public discourse stresses constructive collaboration.
#
# Story seeds and ideas (optional)
# - A political crisis in the Crescent Senate over a new water-ice extraction project that could compromise long-term sustainability.
# - An archaeological discovery within a lava-tube tunnel that hints at ancient lunar life or an alien-technological civilization, triggering a debate about Earth-Moon heritage.
# - A humanitarian mission to repair a distant lunar outpost, revealing hidden factions and a conspiracy around supply chains.
# - A festival that brings together Earth-born diplomats and Moon-born settlers, uncovering cultural tensions and forging new alliances.
# - A disaster in the Iceworks Quarter that forces Luna City to test its resilience and unity under pressure.
#
# Variants you can ask for (tone and genre)
# - Hard sci-fi: Emphasize realism, plausible physics, resource math, and engineering constraints.
# - Space opera: Focus on politics, intrigue, grand architecture, and dramatic characters.
# - Cyberpunk or neo-noir: Shade of corporate power, surveillance, and grit in a high-tech frontier.
# - Mythic or poetic: Rich legends, rituals, and a more symbolic, almost folkloric mood.
#
# Would you like me to tailor Luna City to a specific genre (hard sci-fi, space opera, etc.), or to a certain length (short concept, a full novella bible, or a game setting)? If you share your preferred tone, I can rewrite or expand any section accordingly.
