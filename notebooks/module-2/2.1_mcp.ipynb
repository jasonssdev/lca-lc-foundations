# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys
import asyncio

# Fix for Windows issues in Jupyter notebooks
if sys.platform == "win32":
    # 1. Use ProactorEventLoop for subprocess support
    if not isinstance(asyncio.get_event_loop_policy(), asyncio.WindowsProactorEventLoopPolicy):
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())
    
    # 2. Redirect stderr to avoid fileno() error when launching MCP servers
    if "ipykernel" in sys.modules:
        sys.stderr = sys.__stderr__

# %% [markdown]
# ## Local MCP server

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "local_server": {
                "transport": "stdio",
                "command": "python",
                "args": ["resources/2.1_mcp_server.py"],
            }
    }
)

# %%
# get tools
tools = await client.get_tools()

# get resources
resources = await client.get_resources("local_server")

# get prompts
prompt = await client.get_prompt("local_server", "prompt")
prompt = prompt[0].content
# Out:
#   + Exception Group Traceback (most recent call last):
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#   |     await eval(code_obj, self.user_global_ns, self.user_ns)
#   |   File "/var/folders/_t/h3_2dkhs547fvj9rymbnvxjm0000gn/T/ipykernel_6065/3663964148.py", line 2, in <module>
#   |     tools = await client.get_tools()
#   |             ^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/client.py", line 197, in get_tools
#   |     tools_list = await asyncio.gather(*load_mcp_tool_tasks)
#   |                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/tools.py", line 478, in load_mcp_tools
#   |     async with create_session(
#   |   File "/opt/anaconda3/lib/python3.12/contextlib.py", line 231, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/sessions.py", line 419, in create_session
#   |     async with _create_stdio_session(**params) as session:
#   |   File "/opt/anaconda3/lib/python3.12/contextlib.py", line 231, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/sessions.py", line 230, in _create_stdio_session
#   |     async with (
#   |   File "/opt/anaconda3/lib/python3.12/contextlib.py", line 231, in __aexit__
#   |     await self.gen.athrow(value)
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 182, in stdio_client
#   |     async with (
#   |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 783, in __aexit__
#   |     raise BaseExceptionGroup(
#   | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Exception Group Traceback (most recent call last):
#     |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/mcp/client/stdio/__init__.py", line 189, in stdio_client
#     |     yield read_stream, write_stream
#     |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/sessions.py", line 230, in _create_stdio_session
#     |     async with (
#     |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/mcp/shared/session.py", line 238, in __aexit__
#     |     return await self._task_group.__aexit__(exc_type, exc_val, exc_tb)
#     |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 783, in __aexit__
#     |     raise BaseExceptionGroup(
#     | ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#     +-+---------------- 1 ----------------
#       | Traceback (most recent call last):
#       |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/sessions.py", line 234, in _create_stdio_session
#       |     yield session
#       |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/sessions.py", line 420, in create_session
#       |     yield session
#       |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_mcp_adapters/tools.py", line 481, in load_mcp_tools
#       |     await tool_session.initialize()
#       |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/mcp/client/session.py", line 171, in initialize
#       |     result = await self.send_request(
#       |              ^^^^^^^^^^^^^^^^^^^^^^^^
#       |   File "/Users/jssdev/Dev/Learning/langchain/lca-lc-foundations/.venv/lib/python3.12/site-packages/mcp/shared/session.py", line 306, in send_request
#       |     raise McpError(response_or_error.error)
#       | mcp.shared.exceptions.McpError: Connection closed
#       +------------------------------------

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt=prompt
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       1 from langchain.agents import create_agent
#       3 agent = create_agent(
#       4     model="gpt-5-nano",
#       5     tools=tools,
# ----> 6     system_prompt=prompt
#       7 )
#
# NameError: name 'prompt' is not defined

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Tell me about the langchain-mcp-adapters library")]},
    config=config
)

# %%
from pprint import pprint

pprint(response)

# %% [markdown]
# ## Online MCP

# %%
client = MultiServerMCPClient(
    {
        "time": {
            "transport": "stdio",
            "command": "uvx",
            "args": [
                "mcp-server-time",
                "--local-timezone=America/New_York"
            ]
        }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
)

# %%
from pprint import pprint

# %%
from langchain.messages import HumanMessage


question = HumanMessage(content="What time is it?")

response = await agent.ainvoke(
    {"messages": [question]}
)

pprint(response)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# {'messages': [HumanMessage(content='What time is it?', additional_kwargs={}, response_metadata={}, id='17bc8a48-d364-4aa4-9802-aeab865be0a9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 155, 'prompt_tokens': 296, 'total_tokens': 451, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAp0DK9IGMOHC5Ltmz95u5DifPb3t', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c73f1-1180-78a2-ac1c-4add28239e8c-0', tool_calls=[{'name': 'get_current_time', 'args': {'timezone': 'America/New_York'}, 'id': 'call_mfB6jGzp9tyFIX2nEER27YTH', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 296, 'output_tokens': 155, 'total_tokens': 451, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "timezone": "America/New_York",\n  "datetime": "2026-02-18T22:28:27-05:00",\n  "day_of_week": "Wednesday",\n  "is_dst": false\n}', 'id': 'lc_61c966e1-fc40-421f-a05f-8f700e4a904f'}], name='get_current_time', id='3954ab7c-8b70-40e8-826f-d0201325d66b', tool_call_id='call_mfB6jGzp9tyFIX2nEER27YTH'),
#               AIMessage(content='Current time in New York (America/New_York): Wednesday, February 18, 2026, 10:28:27 PM EST (UTC-5).\n\nWant me to convert this to another time zone?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 565, 'prompt_tokens': 379, 'total_tokens': 944, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAp0GEvDpdWgsqpORY5YyneytFT8a', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c73f1-1deb-7b90-b31d-fd47cdd2b5bf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 379, 'output_tokens': 565, 'total_tokens': 944, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})]}
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://eu.api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://eu.api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
